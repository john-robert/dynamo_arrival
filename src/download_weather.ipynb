# %%
import pandas as pd
import json
import urllib
import urllib.request

# %%
station_dresden = "01050"

# %%
first_date = "2019-01-01"

# %%
last_date = "2019-12-31"

# %%
url = f"https://api.brightsky.dev/weather?date={first_date}&last_date={last_date}&dwd_station_id={station_dresden}"
req = urllib.request.Request(url)
response = urllib.request.urlopen(req)
data = response.read()
values = json.loads(data)

# %%
df_new= pd.DataFrame(values['weather'])

# %%
df_new
# Out:
#                       timestamp  source_id  precipitation pressure_msl  \
# 0     2019-01-01T00:00:00+00:00      96819            0.2         None
# 1     2019-01-01T01:00:00+00:00      96819            0.0         None
# 2     2019-01-01T02:00:00+00:00      96819            0.0         None
# 3     2019-01-01T03:00:00+00:00      96819            0.0         None
# 4     2019-01-01T04:00:00+00:00      96819            0.0         None
# ...                         ...        ...            ...          ...
# 8732  2019-12-30T20:00:00+00:00      96819            0.0         None
# 8733  2019-12-30T21:00:00+00:00      96819            0.0         None
# 8734  2019-12-30T22:00:00+00:00      96819            0.0         None
# 8735  2019-12-30T23:00:00+00:00      96819            0.0         None
# 8736  2019-12-31T00:00:00+00:00      96819            0.0         None
#
#       sunshine  temperature wind_direction wind_speed cloud_cover  dew_point  \
# 0          NaN          6.6           None       None        None        6.2
# 1          NaN          8.2           None       None        None        6.2
# 2          NaN          7.3           None       None        None        5.9
# 3          0.0          8.2           None       None        None        5.0
# 4          0.0          8.4           None       None        None        3.8
# ...        ...          ...            ...        ...         ...        ...
# 8732       0.0          3.8           None       None        None       -2.4
# 8733       NaN          3.4           None       None        None       -2.4
# 8734       NaN          2.6           None       None        None       -2.3
# 8735       NaN          2.5           None       None        None       -2.4
# 8736       NaN          2.2           None       None        None       -2.4
#
#       relative_humidity visibility wind_gust_direction wind_gust_speed  \
# 0                    97       None                None            None
# 1                    87       None                None            None
# 2                    91       None                None            None
# 3                    80       None                None            None
# 4                    73       None                None            None
# ...                 ...        ...                 ...             ...
# 8732                 64       None                None            None
# 8733                 66       None                None            None
# 8734                 70       None                None            None
# 8735                 70       None                None            None
# 8736                 72       None                None            None
#
#      condition         icon
# 0         None  clear-night
# 1          dry  clear-night
# 2          dry  clear-night
# 3          dry  clear-night
# 4          dry  clear-night
# ...        ...          ...
# 8732       dry  clear-night
# 8733       dry  clear-night
# 8734       dry  clear-night
# 8735       dry  clear-night
# 8736       dry  clear-night
#
# [8737 rows x 16 columns]

# %%
df_new.to_pickle("weather_dresden.pkl")
