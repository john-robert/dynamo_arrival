# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data =  pd.read_excel(f"C:/Users/ankit/Documents/Hackaton/dynamo_arrival/excel_postal_code/Hackathon_Bielefeld_30.01.2019_VVKStart_03.12.2018_AL.xlsx")

# %%
data.describe()
# Out:
#        Kartenanzahl  Seriennummer
# count  15788.000000  1.578800e+04
# mean       1.486635  3.944147e+09
# std        2.576433  2.113309e+08
# min        1.000000  3.791733e+09
# 25%        1.000000  3.830820e+09
# 50%        1.000000  3.849458e+09
# 75%        2.000000  3.901302e+09
# max      136.000000  4.850812e+09

# %%
data
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                                                    DEU
# 1                                                                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                                                    DEU
# ...                   ...                     ...                    ...
# 15783                                                                DEU
# 15784                                                                DEU
# 15785                                                                DEU
# 15786                                                                DEU
# 15787                                                                DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data[~data["Adresse VVK-Stelle"].isnull()]
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                                                    DEU
# 1                                                                    DEU
# 3                 Dresden                   01237                    DEU
# 4                                                                    DEU
# 5                 Dresden                   01307                    DEU
# ...                   ...                     ...                    ...
# 15783                                                                DEU
# 15784                                                                DEU
# 15785                                                                DEU
# 15786                                                                DEU
# 15787                                                                DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data["Order Shipping Zip Code"].describe()
# Out:
# count     15788
# unique     1024
# top
# freq       1227
# Name: Order Shipping Zip Code, dtype: object

# %%
data.dtypes
# Out:
# Order Shipping City                object
# Order Shipping Zip Code            object
# Order Shipping Country             object
# Kartenanzahl                        int64
# Kaufdatum                  datetime64[ns]
# Seriennummer                        int64
# Block                              object
# Verkäufer                          object
# Adresse VVK-Stelle                 object
# dtype: object

# %%
shipping_codes = data["Order Shipping Zip Code"]

# %%
shipping_codes
# Out:
# 0
# 1
# 2        3526WP
# 3         01237
# 4
#           ...
# 15783
# 15784
# 15785
# 15786
# 15787
# Name: Order Shipping Zip Code, Length: 15788, dtype: object

# %%
data[~data["Order Shipping Zip Code"].isna()]
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                                                    DEU
# 1                                                                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                                                    DEU
# ...                   ...                     ...                    ...
# 15783                                                                DEU
# 15784                                                                DEU
# 15785                                                                DEU
# 15786                                                                DEU
# 15787                                                                DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data["Seriennummer"].nunique()
# Out:
# 15788

# %%
data["Order Shipping Zip Code"] = data["Order Shipping Zip Code"].astype(str)

# %%
data.dtypes
# Out:
# Order Shipping City                object
# Order Shipping Zip Code            object
# Order Shipping Country             object
# Kartenanzahl                        int64
# Kaufdatum                  datetime64[ns]
# Seriennummer                        int64
# Block                              object
# Verkäufer                          object
# Adresse VVK-Stelle                 object
# dtype: object

# %%
data["Order Shipping Zip Code"].replace('', np.nan, inplace=True)

# %%
data
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                                                    DEU
# 1                                                                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                                                    DEU
# ...                   ...                     ...                    ...
# 15783                                                                DEU
# 15784                                                                DEU
# 15785                                                                DEU
# 15786                                                                DEU
# 15787                                                                DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data.astype(str)['Order Shipping Zip Code'].map(lambda x:  type(x))
# Out:
# 0        <class 'str'>
# 1        <class 'str'>
# 2        <class 'str'>
# 3        <class 'str'>
# 4        <class 'str'>
#              ...
# 15783    <class 'str'>
# 15784    <class 'str'>
# 15785    <class 'str'>
# 15786    <class 'str'>
# 15787    <class 'str'>
# Name: Order Shipping Zip Code, Length: 15788, dtype: object

# %%
data["Order Shipping Zip Code"].replace(' ', np.nan, inplace=True)

# %%
data
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                             NaN                    DEU
# 1                                             NaN                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                             NaN                    DEU
# ...                   ...                     ...                    ...
# 15783                                         NaN                    DEU
# 15784                                         NaN                    DEU
# 15785                                         NaN                    DEU
# 15786                                         NaN                    DEU
# 15787                                         NaN                    DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data[~data["Order Shipping Zip Code"].isna()]
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 5                 Dresden                   01307                    DEU
# 6            Braunschweig                   38104                    DEU
# 7             Markersdorf                   02829                    DEU
# ...                   ...                     ...                    ...
# 15752             Dresden                   01237                    DEU
# 15753             Dresden                   01307                    DEU
# 15754             Dresden                   01067                    DEU
# 15755              Kamenz                   01917                    DEU
# 15774             Leisnig                   04703                    DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data[data["Order Shipping Zip Code"].isna()]
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                             NaN                    DEU
# 1                                             NaN                    DEU
# 4                                             NaN                    DEU
# 143                                           NaN                    DEU
# 146                                           NaN                    DEU
# ...                   ...                     ...                    ...
# 15783                                         NaN                    DEU
# 15784                                         NaN                    DEU
# 15785                                         NaN                    DEU
# 15786                                         NaN                    DEU
# 15787                                         NaN                    DEU
#
#        Kartenanzahl           Kaufdatum  Seriennummer            Block  \
# ...

# %%
data.drop(columns=["Seriennummer","Adresse VVK-Stelle"], inplace=True)

# %%
data["Block"].value_counts()
# Out:
# K3-Steh             1528
# K2-Steh             1514
# K4-Steh             1451
# K1-Steh             1265
# K5-Steh             1217
# N2                   682
# J2                   473
# M2                   464
# J4                   447
# L2                   443
# R2                   431
# J3                   427
# L3                   409
# O2                   338
# B2                   337
# D4 Nichtraucher      309
# C2 Nichtraucher      290
# P2                   231
# O1                   217
# D3 Nichtraucher      217
# P1                   206
# N1                   194
# D2 Nichtraucher      178
# M3                   172
# N3                   171
# C3 Nichtraucher      170
# P3                   145
# F1                   136
# C4 Nichtraucher      127
# B3                   120
# E3                   116
# J1                   115
# J5                   110
# F3                   110
# D5                   109
# E1                   106
# E2                   101
# ...

# %%
zip_dict = {'1km': ['01069'],
 '2km': ['01067',
  '01108',
  '01109',
  '01189',
  '01217',
  '01259',
  '01277',
  '01279',
  '01307',
  '01314',
  '01324',
  '01328',
  '01462',
  '01478'],
 '7km': ['01097',
  '01099',
  '01127',
  '01129',
  '01139',
  '01157',
  '01159',
  '01169',
  '01187',
  '01219',
  '01237',
  '01239',
  '01257',
  '01307',
  '01309',
  '01326',
  '01728'],
 '20km': ['01156',
  '01314',
  '01445',
  '01454',
  '01458',
  '01465',
  '01468',
  '01471',
  '01477',
  '01640',
  '01705',
  '01723',
  '01731',
  '01734',
  '01737',
  '01738',
  '01744',
  '01768',
  '01796',
  '01809',
  '01847']}

# %%
pin_codes =  list(data["Order Shipping Zip Code"])

# %%
data.dtypes
# Out:
# Order Shipping City                object
# Order Shipping Zip Code            object
# Order Shipping Country             object
# Kartenanzahl                        int64
# Kaufdatum                  datetime64[ns]
# Block                              object
# Verkäufer                          object
# dtype: object

# %%
data
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                             NaN                    DEU
# 1                                             NaN                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                             NaN                    DEU
# ...                   ...                     ...                    ...
# 15783                                         NaN                    DEU
# 15784                                         NaN                    DEU
# 15785                                         NaN                    DEU
# 15786                                         NaN                    DEU
# 15787                                         NaN                    DEU
#
#        Kartenanzahl           Kaufdatum            Block           Verkäufer
# ...

# %%
data['Order Shipping Zip Code'].replace(np.nan, " ", inplace=True)

# %%
data
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 0                                                                    DEU
# 1                                                                    DEU
# 2                 Utrecht                  3526WP                    NLD
# 3                 Dresden                   01237                    DEU
# 4                                                                    DEU
# ...                   ...                     ...                    ...
# 15783                                                                DEU
# 15784                                                                DEU
# 15785                                                                DEU
# 15786                                                                DEU
# 15787                                                                DEU
#
#        Kartenanzahl           Kaufdatum            Block           Verkäufer
# ...

# %%
list_distances = []
list_pin_codes = []
for keys in zip_dict:
    list_pin_codes.append(zip_dict[keys])
list_pin_codes=[val for sublist in list_pin_codes for val in sublist]

for i  in range(0,len(data['Order Shipping Zip Code'])):
    #if not (data['Order Shipping Zip Code'][i] == "00"):
        distance = " "
        try:
            #print(data['Order Shipping Zip Code'][i])
            distance = list(zip_dict.keys())[list(list_pin_codes).index(data['Order Shipping Zip Code'][i])]
            #print(distance)
        except:
            distances=  " "  
        list
        list_distances.append(distance)
    
data["Distance_from_pin"] = list_distances

# %%
data["Distance_from_pin"].unique()
# Out:
# array([' ', '2km', '20km', '1km', '7km'], dtype=object)

# %%
data[data['Order Shipping Zip Code'] == "01069"]
# Out:
#       Order Shipping City Order Shipping Zip Code Order Shipping Country  \
# 83                Dresden                   01069                    DEU
# 84                Dresden                   01069                    DEU
# 85                Dresden                   01069                    DEU
# 103               Dresden                   01069                    DEU
# 155               Dresden                   01069                    DEU
# ...                   ...                     ...                    ...
# 15618             Dresden                   01069                    DEU
# 15619             Dresden                   01069                    DEU
# 15681             Dresden                   01069                    DEU
# 15682             Dresden                   01069                    DEU
# 15683             Dresden                   01069                    DEU
#
#        Kartenanzahl           Kaufdatum            Block     Verkäufer  \
# ...
